# %% [markdown]
# <table class="table table-bordered">
#     <tr>
#         <th style="text-align:center; width:25%"><img src='https://www.nus.edu.sg/images/default-source/base/logo.png' style="width: 250px; height: 125px; "></th>
#         <th style="text-align:center;"><h1>Machine Learning in Python</h1><h2>Lab 2c - Decision Tree </h2><h3></h3></th>
#     </tr>
# </table>

# %%
# Import the requried packages
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import linear_model, neighbors, tree, svm, ensemble
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score, cross_validate

# %% [markdown]
# ### 1.Classification

# %% [markdown]
# We will be using the bank marketing campaign data for classification task. We commented out the data scaling part of codes, as Decision Tree is known to perform well even without data scalling, but of course it will perform equally well with data scaling.

# %%
# Loading the data
bank = pd.read_csv('bank.csv')
print(bank.head())
# Encode the categorical data into numbers
bank_cat = bank.select_dtypes(['object']).copy()
for col in bank_cat:
    print(col, ':')
    codes, uniques = pd.factorize(bank_cat[col], sort=True)
    bank[col]=codes
    print(uniques)
print(bank.head())
    
# Set the "deposit" as target/model output and the rest features as model inputs
y = bank['deposit']
X = bank.drop(['deposit'], axis=1)

# Split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

#Sacaling the data into a smaller range (-3 to +3)
#mean = X_train.mean()
#std = X_train.std()

#X_train = (X_train - mean) / std
#X_test = (X_test - mean) / std
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes
# job :
# Index(['admin.', 'blue-collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self-employed', 'services', 'student', 'technician',
#        'unemployed', 'unknown'],
#       dtype='object')
# marital :
# Index(['divorced', 'married', 'single'], dtype='object')
# education :
# Index(['primary', 'secondary', 'tertiary', 'unknown'], dtype='object')
# default :
# Index(['no', 'yes'], dtype='object')
# housing :
# Index(['no', 'yes'], dtype='object')
# loan :
# Index(['no', 'yes'], dtype='object')
# contact :
# Index(['cellular', 'telephone', 'unknown'], dtype='object')
# month :
# Index(['apr', 'aug', 'dec', 'feb', 'jan', 'jul', 'jun', 'mar', 'may', 'nov',
#        'oct', 'sep'],
#       dtype='object')
# poutcome :
# Index(['failure', 'other', 'success', 'unknown'], dtype='object')
# deposit :
# Index(['no', 'yes'], dtype='object')
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# 1    5      8      1467         1     -1         0         3        1
# 2    5      8      1389         1     -1         0         3        1
# 3    5      8       579         1     -1         0         3        1
# 4    5      8       673         2     -1         0         3        1

# %% [markdown]
# #### 1.1 Baseline Model

# %%
X_train
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 10713   45    0        1          3        0     2033        0     0        0
# 8431    56    0        1          0        0      202        1     0        2
# 9060    50    3        2          1        0      799        0     0        1
# 8604    58    0        1          1        0     1464        1     1        2
# 2988    43    4        2          2        0    11891        0     0        0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 1099    29   10        2          0        0      550        0     0        0
# 2514    23    8        2          1        0      431        0     0        0
# 6637    39    4        1          2        0        0        1     0        0
# 2575    60    0        1          1        0      106        0     0        0
# 7336    40    0        0          1        0      274        1     1        0
#
#        day  month  duration  campaign  pdays  previous  poutcome
# 10713   28      8        48         4     -1         0         3
# 8431     9      8       178         2     -1         0         3
# 9060    28      4        63         1     -1         0         3
# 8604     5      6        53        29     -1         0         3
# 2988     4      2       821         5    242         1         2
# ...    ...    ...       ...       ...    ...       ...       ...
# 1099    29      4       801         1     -1         0         3
# 2514    13      1       496         2     -1         0         3
# 6637    11      8       112         1     -1         0         3
# 2575    21      1       216         3     91         1         2
# 7336    25      5        53         4     -1         0         3
#
# [8929 rows x 16 columns]

# %%
#Decision Tree Model
dt_clf = tree.DecisionTreeClassifier(max_depth = 3) # set the depth of tree as 3
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
print('train_acc:', dt_clf.score(X_train, y_train), 
      '\n test_acc:', dt_clf.score(X_test, y_test))
# Out:
# train_acc: 0.7864262515399261
#  test_acc: 0.7792207792207793

# %%
plt.figure(figsize=(25,10))
tree.plot_tree(dt_clf,
               feature_names = X_train.columns,
               class_names = ['No', 'Yes'],
               rounded = True,
               filled= True,
               fontsize =16)
plt.show()

# %% [markdown]
# #### 1.2 Tuning Model Hyperparameter: max_depth

# %%
# Find the best max_depth
depth_range = range(2,12) # ranges from 2 to 12
train_accuracy = []
test_accuracy = []

for d in depth_range:
    dt_clf = tree.DecisionTreeClassifier(max_depth=d)
    dt_clf.fit(X_train, y_train) 
    train_accuracy.append(dt_clf.score(X_train, y_train))
    test_accuracy.append(dt_clf.score(X_test, y_test))
    
#Plot the train & test accuracy
plt.plot(depth_range, train_accuracy, 'bo-', label ='training accuracy')
plt.plot(depth_range, test_accuracy, 'ro-', label = 'testing accuracy')

plt.xlabel('max_depth', fontsize='x-large')
plt.ylabel('Accuracy', fontsize='x-large')

plt.legend(loc='best', shadow=True)
plt.show()

# %%
#Decision Tree Model
dt_clf = tree.DecisionTreeClassifier(max_depth = 7) # set the best max_depth
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
print('train_acc:', dt_clf.score(X_train, y_train), 
      '\n test_acc:', dt_clf.score(X_test, y_test))
# Out:
# train_acc: 0.839511703438235
#  test_acc: 0.8101209135691895

# %% [markdown]
# #### 1.3 Tuning Multiple Model Hyperparameters using GridSearchCV

# %% [markdown]
# The `DecisionTreeClassifier` has a few model hyperparameters which restrict the shape of Decision Tree, e.g:
# * `criterion`: the metrics used to measure the impurity of each node (e.g. gini, entropy and etc.);
# * `min_samples_leaf`: the minimum number of samples a leaf node must have;
# * `min_samples_split`: the minimum number of samples a node must have before it can be split;
# * `max_depth`: the maximum depth of the tree.
#
# Earlier we only adjusted `max_depth` but what if we want to adjust all the above mentioned hyperparameters? It would be a very tedious work to do this manually, i.e. try and explore all the possible combinations and find the best set of values.
#
# Instead you should get Scikit-Learn's `GridSearchCV` to search for you. All you need to do is tell it which hyperparameters you want it to experiment with, and what values to try out, and it will evaluate all the possible combinations of hyperparameter values, using cross-validation.

# %% [markdown]
# K-folds Cross Validation is useful to get the best model hyperparameters. We randomly split the train data into 5 folds (K=5) and then train & validate the Decision Tree model 5 times, picking a different fold for validation every time and training on the other 4 folds. The result is an array containing the 5 accuracy scores for both training and validation scores:

# %%
from sklearn.model_selection import cross_val_score, cross_validate

# Evaluate the Model using K-folds Cross validation
results  = cross_validate(dt_clf, X_train, y_train, scoring='accuracy', cv=5, return_train_score = True)
print('train_score: ', results['train_score'])
print('val_score: ', results['test_score'])
# Out:
# train_score:  [0.84348313 0.84236315 0.83872323 0.8451631  0.84882419]
# val_score:  [0.81522956 0.83146697 0.80795073 0.80907055 0.80896359]

# %%
X_train.shape
# Out:
# (8929, 16)

# %%
# Use GridSearch to find the best combination of model hyperparameters
from sklearn.model_selection import GridSearchCV

dt_clf = tree.DecisionTreeClassifier()

param_grid = { "criterion" : ["gini", "entropy"],              
              "min_samples_leaf" : [1, 5, 10], 
              "min_samples_split" : [10, 12, 16, 20,24], 
              'max_depth' : [5,6,7,8,9,10,11]        
             }

gs_clf = GridSearchCV(dt_clf, param_grid=param_grid, scoring='accuracy', cv= 5, n_jobs=-1)
# cv: number of partitions for cross validation
# n_jobs: number of jobs to run in parallel, -1 means using all processors

gs_clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 6, 7, 8, 9, 10, 11],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [10, 12, 16, 20, 24]},
#              scoring='accuracy')

# %%
print(gs_clf.best_score_)
print(gs_clf.best_params_)
print(gs_clf.best_estimator_)
# Out:
# 0.822711534781886
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=5,
#                        min_samples_split=20)

# %%
cvres = gs_clf.cv_results_
for acc, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(acc, params)
# Out:
# 0.8013218904583109 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8010978635575171 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8012099083754443 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8013218904583109 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8010979262925775 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8013217649881901 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8013217649881901 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8013217649881901 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8014337470710569 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8012097829053234 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8017697560547175 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8017697560547175 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8017697560547175 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8017697560547175 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.801545791888984 {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8122956954338287 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8122956954338287 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8124077402517559 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.812743686500356 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8125197223346226 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8120717312680951 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8121836506159014 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8120716685330347 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.812407614781635 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8121836506159014 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8115111935031571 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8115111935031571 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8115111935031571 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8115111935031571 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8115111935031571 {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8142003946035301 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8142003318684697 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8144245469744449 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8144245469744449 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8140883497856028 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8100570575374606 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8107288872996007 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8112887977139345 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8121847171119286 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8117365378402202 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8122964482545537 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.812744564791202 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.812184466171687 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8124084303374206 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8124084303374206 {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8115124482043659 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8116246812274742 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8120729232342432 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8125210397708915 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8111771920414302 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8099447617792919 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.809608752795631 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8102808334980128 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8120728604991829 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8108408693824675 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.812184466171687 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8130804483047418 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8133044752055356 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8125206006254686 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8121845289067474 {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8130810129202857 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8124089949529644 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8129692817776608 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8136413624800424 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8130812638605274 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8089376131191559 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8097215504342834 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8124094340983874 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8136414252151027 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8130812638605274 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8157681437636646 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.816775982509465 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8167762961847673 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8166641258967193 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8161044036875668 {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8079286451422675 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8090487169111766 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8105049231338672 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8111771293063696 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8101687886800857 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.804568555305661 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8049044388192007 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8090480895605723 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8109520359095486 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8103920000250939 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8145350861509216 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8152071668533034 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8152071668533034 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.81565503244971 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8155432385720246 {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8059125285052431 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8096088155306915 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.809160510788862 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8093847258948372 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8097204839382561 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.804233550082967 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8055772096072472 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8088246272753222 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8102806452928315 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8099448245143522 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8138635700640838 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8147595521971386 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8140875342298173 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8136394804282295 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8150956866509202 {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.7823943463163541 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.7825063283992207 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.7825063283992207 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.7827302925649542 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.7826183104820876 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.7830665524888566 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.7830665524888566 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.7827304180350751 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.7828424001179419 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.7827304180350751 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.7822824897036081 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.7822824897036081 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.7822824897036081 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.7822824897036081 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.7821705076207415 {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8019936574853906 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8021056395682573 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.80199359475033 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8024415858168575 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8022175589160637 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8026656127176514 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8022176843861845 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8018815499324029 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8021055140981366 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8019935320152698 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8022176216511241 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8022176216511241 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8022176216511241 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8022176216511241 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8021056395682574 {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8130817657410108 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8129696581880232 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8127456940222897 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8126335237342417 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.812745443082048 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8124093086282667 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8120733623796663 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8115132637601514 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8117372279258849 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8114010307370428 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8106177207725196 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8106177207725196 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.810281586318738 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.810281586318738 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8106175325673382 {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8164411654919526 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.817001013171226 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8177852641616556 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8183449863708081 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8185688250664207 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8184569684536749 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8184569684536749 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8181209594700143 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8190168161329481 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.819352574176367 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8172248518668386 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8168889056182383 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8168889056182383 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8173370221548867 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8180087264469057 {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8184567175134332 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8184567175134332 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8186808071492875 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8205845652930824 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8200242784683862 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8209206370118036 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8205846280281429 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8209206997468639 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8217045743269311 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8214804219560164 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8190168161329481 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8194649326695964 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8190168161329481 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8193529505867296 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8202486190444823 {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8164402872011067 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8167762334497068 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8173358929237988 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8201355704655882 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8190155614317394 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8193516958855211 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8204717049193698 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.8209197587209577 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.822711534781886 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8213676243173641 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8194642425839318 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8194640543787504 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8192400902130169 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8193522605010649 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8212560813799203 {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 24}
# 0.8126337119394229 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.8142011474242553 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 12}
# 0.8131933714135151 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 16}
# 0.8165525202242151 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.8177843858708098 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 24}
# 0.8135295058672967 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.8138652639107156 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.815769084789571 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.8183446099604457 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.8168887801481175 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 24}
# 0.8144250488549283 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.8145370309377951 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 12}
# 0.8134170219039463 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.8144248606497471 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.8172247263967177 {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 10, 'min_samples_split': 24}

# %%
#Decision Tree Final Model (Option 1)
dt_clf = tree.DecisionTreeClassifier(criterion ='entropy', 
                                     max_depth = 10, 
                                     min_samples_leaf = 5, 
                                     min_samples_split = 20
                                    )
dt_clf.fit(X_train, y_train)

print('train_acc:', dt_clf.score(X_train, y_train), 
      '\n test_acc:', dt_clf.score(X_test, y_test))
# Out:
# train_acc: 0.86146264979281
#  test_acc: 0.8235557545902373

# %%
#Decision Tree Final Model (Option 2)
dt_clf = gs_clf.best_estimator_
dt_clf.fit(X_train, y_train)

print('train_acc:', dt_clf.score(X_train, y_train), 
      '\n test_acc:', dt_clf.score(X_test, y_test))
# Out:
# train_acc: 0.86146264979281
#  test_acc: 0.8244514106583072

# %% [markdown]
# ### 3. Regression
# We will be using the supermarket data for regression task.

# %%
# Loading the data
supermarket = pd.read_csv('supermarket.csv')
print(supermarket.head())

# Encode the categorical data into numbers
supermarket_cat = supermarket.select_dtypes(['object']).copy()
for col in supermarket_cat:
    print(col, ':')
    codes, uniques = pd.factorize(supermarket_cat[col], sort=True)
    supermarket[col]=codes
    print(uniques)
print(supermarket.head())

# Set the "Sales" as target/model output and the rest features as model inputs
y = supermarket['Item_Outlet_Sales']
X = supermarket.drop(['Item_Outlet_Sales'], axis=1)

# Split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

#Sacaling the data into a smaller range (-3 to +3)
# mean = X_train.mean()
# std = X_train.std()

# X_train = (X_train - mean) / std
# X_test = (X_test - mean) / std
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
# 3  182.0950            OUT010                       1998         NaN
# 4   53.8614            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700
# 3               Tier 3      Grocery Store           732.3800
# 4               Tier 3  Supermarket Type1           994.7052
# Item_Fat_Content :
# Index(['Low Fat', 'Regular'], dtype='object')
# Item_Type :
# Index(['Baking Goods', 'Breads', 'Breakfast', 'Canned', 'Dairy',
#        'Frozen Foods', 'Fruits and Vegetables', 'Hard Drinks',
#        'Health and Hygiene', 'Household', 'Meat', 'Others', 'Seafood',
#        'Snack Foods', 'Soft Drinks', 'Starchy Foods'],
#       dtype='object')
# Outlet_Identifier :
# Index(['OUT010', 'OUT013', 'OUT017', 'OUT018', 'OUT019', 'OUT027', 'OUT035',
#        'OUT045', 'OUT046', 'OUT049'],
#       dtype='object')
# Outlet_Size :
# Index(['High', 'Medium', 'Small'], dtype='object')
# Outlet_Location_Type :
# Index(['Tier 1', 'Tier 2', 'Tier 3'], dtype='object')
# Outlet_Type :
# Index(['Grocery Store', 'Supermarket Type1', 'Supermarket Type2',
#        'Supermarket Type3'],
#       dtype='object')
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 0         0.016047          4  249.8092
# 1         5.92                 1         0.019278         14   48.2692
# 2        17.50                 0         0.016760         10  141.6180
# 3        19.20                 1         0.000000          6  182.0950
# 4         8.93                 0         0.000000          9   53.8614
#
#    Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0                  9                       1999            1
# 1                  3                       2009            1
# 2                  9                       1999            1
# 3                  0                       1998           -1
# 4                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052

# %%
#Decision Tree Model
dt_reg = tree.DecisionTreeRegressor(criterion = 'mse', max_depth=3)
dt_reg.fit(X_train, y_train)
# Out:
# C:\Users\aixin\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# DecisionTreeRegressor(criterion='mse', max_depth=3)

# %%
print('train_mae:', mean_absolute_error(dt_reg.predict(X_train), y_train), 
      '\n test_mae:', mean_absolute_error(dt_reg.predict(X_test), y_test))
# Out:
# train_mae: 764.9480125757958
#  test_mae: 768.317898765845

# %%
plt.figure(figsize=(25,10))
tree.plot_tree(dt_reg,
               feature_names = X_train.columns,
               rounded = True,
               filled= True,
               precision =2, 
               fontsize =16)
plt.show()

# %%
# Use GridSearch to find the best combination of model hyperparameters

param_grid = {"criterion" : ["mse", "friedman_mse"], 
              'max_depth' : [2,3,4,5,6,7]}

gs_reg = GridSearchCV(dt_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv= 5, n_jobs=-1)

gs_reg.fit(X_train, y_train)
# Out:
# C:\Users\aixin\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=3),
#              n_jobs=-1,
#              param_grid={'criterion': ['mse', 'friedman_mse'],
#                          'max_depth': [2, 3, 4, 5, 6, 7]},
#              scoring='neg_mean_squared_error')

# %%
print(gs_reg.best_score_)
print(gs_reg.best_params_)
print(gs_reg.best_estimator_)
# Out:
# -962167.5359574768
# {'criterion': 'mse', 'max_depth': 5}
# DecisionTreeRegressor(criterion='mse', max_depth=5)

# %%
#Decision Tree Final Model
dt_reg = gs_reg.best_estimator_ 
dt_reg.fit(X_train, y_train)

print('train_mae:', mean_absolute_error(dt_reg.predict(X_train), y_train), 
      '\n test_mae:', mean_absolute_error(dt_reg.predict(X_test), y_test))
# Out:
# train_mae: 700.8810621525724
#  test_mae: 696.046335030238
# C:\Users\aixin\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:397: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(

# %%
dt_reg.score(X_test, y_test)
# Out:
# 0.5719946104021211

# %% [markdown]
# ### 4. Exercise:
# Tuning model hyperparameters for the above two models (classification and regression) and try your best to further improve the model performance.

# %%
# Import the requried packages
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import linear_model, neighbors, tree, svm, ensemble
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score, cross_validate

# %% [markdown]
# #### Classification

# %%
# Loading the data
bank = pd.read_csv('bank.csv')
print(bank.head())

# Encode the categorical data into numbers
bank_cat = bank.select_dtypes(['object']).copy()
for col in bank_cat:
    print(col, ':')
    codes, uniques = pd.factorize(bank_cat[col], sort=True)
    bank[col]=codes
    print(uniques)
print(bank.head())
    
# Set the "deposit" as target/model output and the rest features as model inputs
y = bank['deposit']
X = bank.drop(['deposit'], axis=1)

# Split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

mean = X_train.mean()
std = X_train.std()

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes
# job :
# Index(['admin.', 'blue-collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self-employed', 'services', 'student', 'technician',
#        'unemployed', 'unknown'],
#       dtype='object')
# marital :
# Index(['divorced', 'married', 'single'], dtype='object')
# education :
# Index(['primary', 'secondary', 'tertiary', 'unknown'], dtype='object')
# default :
# Index(['no', 'yes'], dtype='object')
# housing :
# Index(['no', 'yes'], dtype='object')
# loan :
# Index(['no', 'yes'], dtype='object')
# contact :
# Index(['cellular', 'telephone', 'unknown'], dtype='object')
# month :
# Index(['apr', 'aug', 'dec', 'feb', 'jan', 'jul', 'jun', 'mar', 'may', 'nov',
#        'oct', 'sep'],
#       dtype='object')
# poutcome :
# Index(['failure', 'other', 'success', 'unknown'], dtype='object')
# deposit :
# Index(['no', 'yes'], dtype='object')
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# 1    5      8      1467         1     -1         0         3        1
# 2    5      8      1389         1     -1         0         3        1
# 3    5      8       579         1     -1         0         3        1
# 4    5      8       673         2     -1         0         3        1

# %%
msl = range(2, 20)
mss = range(5, 100)
md = range(2, 20)

# %%
from sklearn.model_selection import GridSearchCV

dt_clf = tree.DecisionTreeClassifier()

param_grid = { "criterion" : ["gini", "entropy"],              
              "min_samples_leaf" : msl, 
              "min_samples_split" : mss, 
              'max_depth' : md        
             }

gs_clf_v1 = GridSearchCV(dt_clf, param_grid=param_grid, scoring='accuracy', cv= 3, n_jobs=-1)
gs_clf_v2 = GridSearchCV(dt_clf, param_grid=param_grid, scoring='accuracy', cv= 5, n_jobs=-1)

gs_clf_v1.fit(X_train, y_train)
gs_clf_v2.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 20),
#                          'min_samples_leaf': range(2, 20),
#                          'min_samples_split': range(5, 100)},
#              scoring='accuracy')

# %%
print(gs_clf_v1.best_score_)
print(gs_clf_v1.best_params_)
print(gs_clf_v1.best_estimator_)
# Out:
# 0.8314481364294718
# {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 8, 'min_samples_split': 70}
# DecisionTreeClassifier(criterion='entropy', max_depth=17, min_samples_leaf=8,
#                        min_samples_split=70)

# %%
print(gs_clf_v2.best_score_)
print(gs_clf_v2.best_params_)
print(gs_clf_v2.best_estimator_)
# Out:
# 0.83559223465422
# {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 13, 'min_samples_split': 79}
# DecisionTreeClassifier(criterion='entropy', max_depth=15, min_samples_leaf=13,
#                        min_samples_split=79)

# %%
dt_clf = gs_clf_v1.best_estimator_
dt_clf.fit(X_train, y_train)

print('train_acc:', dt_clf.score(X_train, y_train), 
      '\n test_acc:', dt_clf.score(X_test, y_test))
# Out:
# train_acc: 0.8630305745324225
#  test_acc: 0.8334079713390058

# %%
dt_clf = gs_clf_v2.best_estimator_
dt_clf.fit(X_train, y_train)

print('train_acc:', dt_clf.score(X_train, y_train), 
      '\n test_acc:', dt_clf.score(X_test, y_test))
# Out:
# train_acc: 0.8600067196774555
#  test_acc: 0.8329601433049709

# %% [markdown]
# #### Regression

# %%
# Loading the data
supermarket = pd.read_csv('supermarket.csv')
print(supermarket.head())

# Encode the categorical data into numbers
supermarket_cat = supermarket.select_dtypes(['object']).copy()
for col in supermarket_cat:
    print(col, ':')
    codes, uniques = pd.factorize(supermarket_cat[col], sort=True)
    supermarket[col]=codes
    print(uniques)
print(supermarket.head())

# Set the "Sales" as target/model output and the rest features as model inputs
y = supermarket['Item_Outlet_Sales']
X = supermarket.drop(['Item_Outlet_Sales'], axis=1)

# Split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

#Sacaling the data into a smaller range (-3 to +3)
mean = X_train.mean()
std = X_train.std()

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
# 3  182.0950            OUT010                       1998         NaN
# 4   53.8614            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700
# 3               Tier 3      Grocery Store           732.3800
# 4               Tier 3  Supermarket Type1           994.7052
# Item_Fat_Content :
# Index(['Low Fat', 'Regular'], dtype='object')
# Item_Type :
# Index(['Baking Goods', 'Breads', 'Breakfast', 'Canned', 'Dairy',
#        'Frozen Foods', 'Fruits and Vegetables', 'Hard Drinks',
#        'Health and Hygiene', 'Household', 'Meat', 'Others', 'Seafood',
#        'Snack Foods', 'Soft Drinks', 'Starchy Foods'],
#       dtype='object')
# Outlet_Identifier :
# Index(['OUT010', 'OUT013', 'OUT017', 'OUT018', 'OUT019', 'OUT027', 'OUT035',
#        'OUT045', 'OUT046', 'OUT049'],
#       dtype='object')
# Outlet_Size :
# Index(['High', 'Medium', 'Small'], dtype='object')
# Outlet_Location_Type :
# Index(['Tier 1', 'Tier 2', 'Tier 3'], dtype='object')
# Outlet_Type :
# Index(['Grocery Store', 'Supermarket Type1', 'Supermarket Type2',
#        'Supermarket Type3'],
#       dtype='object')
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 0         0.016047          4  249.8092
# 1         5.92                 1         0.019278         14   48.2692
# 2        17.50                 0         0.016760         10  141.6180
# 3        19.20                 1         0.000000          6  182.0950
# 4         8.93                 0         0.000000          9   53.8614
#
#    Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0                  9                       1999            1
# 1                  3                       2009            1
# 2                  9                       1999            1
# 3                  0                       1998           -1
# 4                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052

# %%
dt_reg = tree.DecisionTreeRegressor()

param_grid = {"criterion" : ["squared_error", "friedman_mse", "absolute_error", "poisson"], 
              "min_samples_leaf" : range(2, 30), 
              # "min_samples_split" : range(4, 30), 
              # "max_features" : [1.0, "sqrt", "log2"],
              'max_depth' : range(2, 10)        
             }

gs_reg_v1 = GridSearchCV(dt_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3, n_jobs=-1)
gs_reg_v2 = GridSearchCV(dt_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5, n_jobs=-1)

gs_reg_v1.fit(X_train, y_train)
gs_reg_v2.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': range(2, 10),
#                          'min_samples_leaf': range(2, 30)},
#              scoring='neg_mean_squared_error')

# %%
print(gs_reg_v1.best_score_)
print(gs_reg_v1.best_params_)
print(gs_reg_v1.best_estimator_)
# Out:
# -953997.4544938052
# {'criterion': 'poisson', 'max_depth': 5, 'min_samples_leaf': 27}
# DecisionTreeRegressor(criterion='poisson', max_depth=5, min_samples_leaf=27)

# %%
print(gs_reg_v2.best_score_)
print(gs_reg_v2.best_params_)
print(gs_reg_v2.best_estimator_)
# Out:
# -951075.6702356448
# {'criterion': 'poisson', 'max_depth': 5, 'min_samples_leaf': 29}
# DecisionTreeRegressor(criterion='poisson', max_depth=5, min_samples_leaf=29)

# %%
dt_reg_v1 = gs_reg_v1.best_estimator_ 
dt_reg_v1.fit(X_train, y_train)

print('train_mae:', mean_absolute_error(dt_reg_v1.predict(X_train), y_train), 
      '\n test_mae:', mean_absolute_error(dt_reg_v1.predict(X_test), y_test))
# Out:
# train_mae: 697.2389279478648
#  test_mae: 696.7376207484104

# %%
dt_reg_v2 = gs_reg_v2.best_estimator_ 
# dt_reg_v2 = tree.DecisionTreeRegressor(criterion='friedman_mse', max_depth=5)
dt_reg_v2.fit(X_train, y_train)

print('train_mae:', mean_absolute_error(dt_reg_v2.predict(X_train), y_train), 
      '\n test_mae:', mean_absolute_error(dt_reg_v2.predict(X_test), y_test))
# Out:
# train_mae: 697.310675209418
#  test_mae: 697.019083259596

# %%
dt_reg_v1.score(X_test, y_test)
# Out:
# 0.5699763040338367

# %%
dt_reg_v2.score(X_test, y_test)
# Out:
# 0.5699259018580991
